# %%
import pandas as pd
file_path = "D:\FinScope 2024 Rwanda.dta"
df = pd.read_stata(file_path)

# %%
df.head()
# Out:
#      key      a1         a2     a6       hh_wt       pop_wt  hh_size hh_head  \
# 0  11838    East    Gatsibo  Rural  519.583516  1168.281635        5    male
# 1  12132    East    Kayonza  Rural  367.836964   331.291150        5    male
# 2   1328  Kigali   Kicukiro  Urban  258.755933   283.327154        4    male
# 3  11377    East  Nyagatare  Rural  369.340969   656.777371        1    male
# 4  10659    East  Rwamagana  Rural  256.832033   757.121752        5    male
#
#                bo  b1  ...    d1c11                d1a13  \
# 0  Household head  60  ...     Walk  Between 3Km and 5Km
# 1  Household head  55  ...     Moto       Less than 500m
# 2  Household head  33  ...     Walk  Between 1Km and 2Km
# 3  Household head  76  ...  Vehicle        More than 5Km
# 4  Spouse/partner  53  ...       NA  Between 3Km and 5Km
#
#                        d1b13 d1c13           d1a14                      d1b14  \
# ...

# %%
df.shape
# Out:
# (13994, 2442)

# %%
df.to_csv("finscope_2024_rwanda.csv", index = "false")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\isaac'
